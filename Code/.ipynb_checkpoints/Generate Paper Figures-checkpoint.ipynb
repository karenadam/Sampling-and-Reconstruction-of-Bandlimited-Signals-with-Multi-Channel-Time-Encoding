# %%
import Figure1
import Figure3
import Figure4
import Figure7
import Figure8
import Figure9
import Figure10
import os

# %%
# %matplotlib inline
Figure1.Generate()
# Out:
# WARNING    /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
#  [py.warnings]
# WARNING    /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
#  [py.warnings]
# WARNING    /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:32: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial)
#  [py.warnings]
# WARNING    /anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:28: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial)
#  [py.warnings]
# ...

# %%
Figure3.Generate()

# %%
Figure4.Generate()

# %%
Figure7.Generate()

# %%
figure8_data_filename = "Data/Figure8_VarNumChannels.pkl"

if(not os.path.isfile(figure8_data_filename)):
    Figure8.GetData()
Figure8.Generate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-4a05abf3d812> in <module>()
#       1 figure8_data_filename = "Data/Figure8_VarNumChannels.pkl"
#       2
# ----> 3 if(not os.path.isfile(figure8_data_filename)):
#       4     Figure8.GetData()
#       5 Figure8.Generate()
#
# NameError: name 'os' is not defined
